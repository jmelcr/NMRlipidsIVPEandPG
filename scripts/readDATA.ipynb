# %%
import os
import numpy as np
import json
import matplotlib.pyplot as plt
import mdtraj
import urllib.request
import yaml
import pprint
from OrderParameter import *

# SAMULI: Also this should be maybe moved to the external code that will be imported
# Download link
def download_link(doi, file):
    if "zenodo" in doi.lower():
        zenodo_entry_number = doi.split(".")[2]
        return 'https://zenodo.org/record/' + zenodo_entry_number + '/files/' + file
    else:
        print ("DOI provided: {0}".format(doi))
        print ("Repository not validated. Please upload the data for example to zenodo.org")
        return ""

# %%
# Demonstration of reading the databank
# Currently lists some information on the simulations in the databank

# List of lipids that will be analyzed
lipids = {'POPC', 'POPG','POPE','POPS'} 
angles = []

# This walks through the files in the databank
# Dictionaries saved as README.yaml are read into 'readme' dictionary

count = 0

for subdir, dirs, files in os.walk(r'../Data/Simulations/'):
    for filename in files:
        filepath = subdir + os.sep + filename
        if filepath.endswith("README.yaml"):
            READMEfilepath = subdir + '/README.yaml'
            with open(READMEfilepath) as yaml_file:
                readme = yaml.load(yaml_file, Loader=yaml.FullLoader)
                #for molname in lipids:
                doi = readme.get('DOI')
                trj = readme.get('TRJ')
                tpr = readme.get('TPR')
                trj_name = subdir + '/' + readme.get('TRJ')[0][0]
                tpr_name = subdir + '/' + readme.get('TPR')[0][0]
                gro_name = subdir + '/conf.gro'
                trj_url = download_link(doi, trj[0][0])
                tpr_url = download_link(doi, tpr[0][0])
                EQtime=float(readme.get('TIMELEFTOUT'))*1000
                
                #if('CHARMM' in readme.get('FF')):
                #print(lipids[0])
                #if('10.5281/zenodo.3241243'  in readme.get('DOI') or '10.5281/zenodo.3832219' in readme.get('DOI')):
                #    !grep "M_G3C5_M M_G3C5H1_M" {subdir}/POPGOrderParameters.dat 
                #if('10.5281/zenodo.4005515'  in readme.get('DOI')):
                #    print(subdir)
                #print(readme.get('SYSTEM'),readme.get('FF'),readme.get('NCAL'))
                
                
                #if(readme.get('NPOPC')[0] > 0 or readme.get('NPOPG')[0] > 0 ):
                #    print(2*readme.get('NPOPC')[0],2*readme.get('NPOPG')[0],readme.get('TEMPERATURE'),readme.get('FF'))
                #    count = count + 1
                #    print(count)
                    
                if(readme.get('NPOPC')[0] > 0):
                    print(readme)
                    print(readme.get('TEMPERATURE'))
# Out:
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': '??', 'POT': 'M_K_M', 'TIMELEFTOUT': '100', 'SYSTEM': 'POPC50%chol_T303K', 'DOI': '10.5281/zenodo.14068', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'CHOL': 'CHOL', 'TEMPERATURE': '303', 'NSOL': 0, 'NPOPE': [0, 0], 'FF': 'CHARMM36', 'TRJLENGTH': 200020.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POPG', 'PREEQTIME': '0', 'MAPPING_DICT': {'POPC': 'mappingPOPCcharmm.txt', 'CHOL': 'mappingCHOLESTEROLcharmm.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['POPC_50CHL.xtc']], 'NPOPC': [40, 40], 'NPOPG': [0, 0], 'NSOD': 0, 'TPR': [['POPC_50CHL.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 0, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCcharmm.txt,CHOL,mappingCHOLESTEROLcharmm.txt', 'CLA': 'M_CL_M'}
# 303
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': 'http://www.fos.su.se/~sasha/SLipids/, https://bitbucket.org/hseara/ions/', 'POT': 'M_K_M', 'TIMELEFTOUT': '500', 'SYSTEM': 'POPC_T298K', 'DOI': '10.5281/zenodo.3613573', 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 12800, 'NPOPE': [0, 0], 'FF': 'Slipids', 'TRJLENGTH': 1000100.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POPG', 'PREEQTIME': '0', 'MAPPING_DICT': {'POPG': 'mappingPOPGslipids.txt', 'POPC': 'mappingPOPCslipids.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['PCPG_CA1000_extend.xtc']], 'NPOPC': [64, 64], 'NPOPG': [64, 64], 'NSOD': 128, 'TPR': [['PCPG_CA1000.tpr']], 'NPOT': '0', 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': '0', 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCslipids.txt,POPG,mappingPOPGslipids.txt', 'CLA': 'M_CL_M'}
# 298
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': 'NMRlipids IVa', 'POT': 'M_K_M', 'TIMELEFTOUT': '20', 'SYSTEM': 'POPC10%DHMDMAB_T313K', 'DOI': '10.5281/zenodo.1288297', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'CHOL': 'CHOL', 'TEMPERATURE': '313', 'NSOL': 7966, 'NPOPE': [0, 0], 'FF': 'CHARMM36', 'TRJLENGTH': 200010.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POPG', 'PREEQTIME': '0', 'MAPPING_DICT': {'DHMDMAB': 'mappingDHMDMABcharmm.txt', 'POPC': 'mappingPOPCcharmm.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['run20.xtc']], 'NPOPC': [50, 50], 'NPOPG': [0, 0], 'NSOD': 0, 'TPR': [['run20.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 30, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCcharmm.txt,DHMDMAB,mappingDHMDMABcharmm.txt', 'CLA': 'M_CL_M'}
# 313
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': 'CHARMM-GUI', 'POT': 'M_K_M', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC:POPG(4:1)_T298K', 'DOI': '10.5281/zenodo.3996952', 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 26280, 'NPOPE': [0, 0], 'FF': 'CHARMM36', 'TRJLENGTH': 300020.0, 'POPC': 'POPC', 'FF_DATE': '?/?/2020', 'POPG': 'POPG', 'PREEQTIME': '100', 'MAPPING_DICT': {'POPG': 'mappingPOPGcharmm.txt', 'POPC': 'mappingPOPCcharmm.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['100-400ns.xtc']], 'NPOPC': [175, 175], 'NPOPG': [44, 44], 'NSOD': 0, 'TPR': [['run_400ns.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 0, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCcharmm.txt,POPG,mappingPOPGcharmm.txt', 'CLA': 'M_CL_M'}
# 298
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': 'CHARMM-GUI', 'POT': 'M_K_M', 'TIMELEFTOUT': '50', 'SYSTEM': 'POPC_T300K', 'DOI': '10.5281/zenodo.1306821', 'NPOPS': [0, 0], 'TEMPERATURE': '300', 'NSOL': 9102, 'NPOPE': [64, 64], 'FF': 'CHARMM36', 'TRJLENGTH': 300100.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POPG', 'PREEQTIME': '0', 'MAPPING_DICT': {'POPE': 'mappingPOPEcharmm.txt', 'POPC': 'mappingPOPCcharmm.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['md_dt100_OK_centered.xtc']], 'NPOPC': [64, 64], 'NPOPG': [0, 0], 'NSOD': 0, 'TPR': [['md.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 0, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCcharmm.txt,POPE,mappingPOPEcharmm.txt', 'CLA': 'M_CL_M'}
# 300
# {'GRO': '/media/osollila/Data/tmp/DATABANK/tmp_6-205652/0/conf.gro', 'SOD': 'NA', 'ID': 0, 'NCAL': 0, 'SOL': 'SOL', 'FF_SOURCE': '??', 'POT': 'K', 'TIMELEFTOUT': '100', 'SYSTEM': 'POPC_T300K', 'DOI': '10.5281/zenodo.1402417', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'TEMPERATURE': '300', 'NSOL': 10342, 'NPOPE': [0, 0], 'FF': 'berger', 'TRJLENGTH': 300100.0, 'POPC': 'POPC', 'FF_DATE': '?/?/????', 'POPG': 'POPG', 'PREEQTIME': '0', 'UADICTIONARY': {'POPC': 'Berger_POPC'}, 'MAPPING_DICT': {'POPC': 'mappingPOPCberger.txt'}, 'CAL': 'CA', 'UNITEDATOM': 'POPC,Berger_POPC', 'TRJ': [['md_dt100_OK_centered.xtc']], 'NPOPC': [128, 128], 'NPOPG': [0, 0], 'NSOD': 0, 'TPR': [['md.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 0, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCberger.txt', 'CLA': 'CL'}
# 300
# {'GRO': '/media/osollila/Data/tmp/DATABANK/tmp_6-612937/0/conf.gro', 'SOD': 'NA', 'ID': 0, 'NCAL': 0, 'SOL': 'SOL', 'FF_SOURCE': '??', 'POT': 'K', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC_T310K', 'DOI': '10.5281/zenodo.3240156', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'TEMPERATURE': '310', 'NSOL': 25000, 'NPOPE': [0, 0], 'FF': 'Slipids', 'TRJLENGTH': 100010.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POG', 'PREEQTIME': '400', 'MAPPING_DICT': {'POPG': 'mappingPOPGslipids.txt', 'POPC': 'mappingPOPCslipids.txt'}, 'CAL': 'CA', 'TRJ': [['total_4_500.xtc']], 'NPOPC': [175, 175], 'NPOPG': [75, 75], 'NSOD': 150, 'TPR': [['md_0.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 0, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCslipids.txt,POPG,mappingPOPGslipids.txt', 'CLA': 'CL'}
# 310
# {'SOD': 'NA', 'ID': 0, 'NCAL': 0, 'SOL': 'SOL', 'FF_SOURCE': 'NMRlipidsIV', 'POT': 'K', 'TIMELEFTOUT': '15', 'SYSTEM': 'POPC:POPG(1:1)_T298K', 'DOI': '10.5281/zenodo.3859339', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 29865, 'NPOPE': [0, 0], 'FF': 'lipid17ecc', 'TRJLENGTH': 347500.0, 'POPC': 'POPC', 'FF_DATE': '?/?/2020', 'POPG': 'POPG', 'PREEQTIME': '0', 'MAPPING_DICT': {'POPG': 'mappingPOPGlipid17ecc.txt', 'POPC': 'mappingPOPClipid17ecc.txt'}, 'CAL': 'CA', 'TRJ': [['traj.xtc']], 'NPOPC': [75, 75], 'NPOPG': [76, 74], 'NSOD': 150, 'TPR': [['topol.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 0, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPClipid17ecc.txt,POPG,mappingPOPGlipid17ecc.txt', 'CLA': 'CL'}
# 298
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': '0', 'SOL': 'M_SOL_M', 'FF_SOURCE': '10.5281/zenodo.3725637', 'POT': 'M_K_M', 'TIMELEFTOUT': '200', 'SYSTEM': 'POPC:POPE(1:1)_T300K', 'DOI': '10.5281/zenodo.3725637', 'NPOPS': [0, 0], 'TEMPERATURE': '300', 'NSOL': 5120, 'NPOPE': [32, 32], 'FF': 'MacRog', 'TRJLENGTH': 500100.0, 'POPC': 'POPC', 'FF_DATE': '26/3/2020', 'POPG': 'POPG', 'PREEQTIME': '0', 'MAPPING_DICT': {'POPE': 'mappingPOPEmacrogFUCHS.txt', 'POPC': 'mappingPOPCmacrogFUCHS.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['md_OK_100.xtc']], 'NPOPC': [32, 32], 'NPOPG': [0, 0], 'NSOD': 0, 'TPR': [['md.tpr']], 'NPOT': '0', 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': '0', 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCmacrogFUCHS.txt,POPE,mappingPOPEmacrogFUCHS.txt', 'CLA': 'M_CL_M'}
# 300
# {'SOD': 'SOD', 'ID': 0, 'NCAL': 57, 'SOL': 'TIP3', 'FF_SOURCE': 'CHARMM-GUI', 'POT': 'K', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC:POPG(1:1)+100mMCaCl_T298K', 'DOI': '10.5281/zenodo.4005515', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 31329, 'NPOPE': [0, 0], 'FF': 'CHARMM36', 'TRJLENGTH': 300020.0, 'POPC': 'POPC', 'FF_DATE': '?/?/2020', 'POPG': 'POPG', 'PREEQTIME': '100', 'MAPPING_DICT': {'POPG': 'mappingPOPGcharmm.txt', 'POPC': 'mappingPOPCcharmm.txt'}, 'CAL': 'CAL', 'TRJ': [['100-400ns.xtc']], 'NPOPC': [75, 75], 'NPOPG': [75, 75], 'NSOD': 150, 'TPR': [['run_400ns.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 114, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCcharmm.txt,POPG,mappingPOPGcharmm.txt', 'CLA': 'CLA'}
# 298
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 47, 'SOL': 'M_SOL_M', 'FF_SOURCE': 'CHARMM-GUI', 'POT': 'M_K_M', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC:POPG(4:1)+0.1MCaCl_T298K', 'DOI': '10.5281/zenodo.3997019', 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 26280, 'NPOPE': [0, 0], 'FF': 'CHARMM36', 'TRJLENGTH': 300020.0, 'POPC': 'POPC', 'FF_DATE': '?/?/2020', 'POPG': 'POPG', 'PREEQTIME': '100', 'MAPPING_DICT': {'POPG': 'mappingPOPGcharmm.txt', 'POPC': 'mappingPOPCcharmm.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['100-400ns.xtc']], 'NPOPC': [175, 175], 'NPOPG': [44, 44], 'NSOD': 0, 'TPR': [['run_400ns.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 94, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCcharmm.txt,POPG,mappingPOPGcharmm.txt', 'CLA': 'M_CL_M'}
# 298
# {'SOD': 'NA', 'ID': 0, 'NCAL': 569, 'SOL': 'SOL', 'FF_SOURCE': 'NMRlipidsIV', 'POT': 'K', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC:POPG(1:1)_T298K_1000mM_CaCl', 'DOI': '10.5281/zenodo.3864993', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 29865, 'NPOPE': [0, 0], 'FF': 'lipid17', 'TRJLENGTH': 200020.0, 'POPC': 'system1', 'FF_DATE': '?/?/2020', 'POPG': 'system2', 'PREEQTIME': '520', 'MAPPING_DICT': {'POPG': 'mappingPOPGlipid17.txt', 'POPC': 'mappingPOPClipid17.txt'}, 'CAL': 'CA', 'TRJ': [['traj.xtc']], 'NPOPC': [75, 75], 'NPOPG': [76, 74], 'NSOD': 150, 'TPR': [['run3.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 1138, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPClipid17.txt,POPG,mappingPOPGlipid17.txt', 'CLA': 'CL'}
# 298
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': '??', 'POT': 'M_K_M', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC_T310K', 'DOI': '10.5281/zenodo.3235552', 'NPOPS': [0, 0], 'TEMPERATURE': '310', 'NSOL': 25000, 'NPOPE': [0, 0], 'FF': 'Slipids', 'TRJLENGTH': 100010.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POPG', 'PREEQTIME': '400', 'MAPPING_DICT': {'POPC': 'mappingPOPCslipids.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['total_4_500.xtc']], 'NPOPC': [250, 250], 'NPOPG': [0, 0], 'NSOD': 0, 'TPR': [['md_0.tpr']], 'NPOT': '0', 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': '0', 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCslipids.txt', 'CLA': 'M_CL_M'}
# 310
# {'SOD': 'NA', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': 'http://www.fos.su.se/~sasha/SLipids/, https://bitbucket.org/hseara/ions/', 'POT': 'M_K_M', 'TIMELEFTOUT': '500', 'SYSTEM': 'POPC_T298K', 'DOI': '10.5281/zenodo.3613573', 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 12800, 'NPOPE': [0, 0], 'FF': 'Slipids', 'TRJLENGTH': 1000100.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POPG', 'PREEQTIME': '0', 'MAPPING_DICT': {'POPG': 'mappingPOPGslipids.txt', 'POPC': 'mappingPOPCslipidsECCions.txt'}, 'CAL': 'CA', 'TRJ': [['PCPG_CA100_extend.xtc']], 'NPOPC': [64, 64], 'NPOPG': [64, 64], 'NSOD': 0, 'TPR': [['PCPG_CA100.tpr']], 'NPOT': '0', 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': '0', 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCslipidsECCions.txt,POPG,mappingPOPGslipids.txt', 'CLA': 'M_CL_M'}
# 298
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': 'NMRlipids IVa', 'POT': 'M_K_M', 'TIMELEFTOUT': '20', 'SYSTEM': 'POPC50%DHMDMAB_T313K', 'DOI': '10.5281/zenodo.1288297', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'CHOL': 'CHOL', 'TEMPERATURE': '313', 'NSOL': 7966, 'NPOPE': [0, 0], 'FF': 'CHARMM36', 'TRJLENGTH': 200010.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POPG', 'PREEQTIME': '0', 'MAPPING_DICT': {'DHMDMAB': 'mappingDHMDMABcharmm.txt', 'POPC': 'mappingPOPCcharmm.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['run50.xtc']], 'NPOPC': [50, 50], 'NPOPG': [0, 0], 'NSOD': 0, 'TPR': [['run50.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 88, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCcharmm.txt,DHMDMAB,mappingDHMDMABcharmm.txt', 'CLA': 'M_CL_M'}
# 313
# {'SOD': 'NA', 'ID': 0, 'NCAL': 54, 'SOL': 'SOL', 'FF_SOURCE': 'NMRlipidsIV', 'POT': 'K', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC:POPG(1:1)_T298K_100mM_CaCl', 'DOI': '10.5281/zenodo.3855729', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 29865, 'NPOPE': [0, 0], 'FF': 'lipid17ecc', 'TRJLENGTH': 300020.0, 'POPC': 'POPC', 'FF_DATE': '?/?/2020', 'POPG': 'POPG', 'PREEQTIME': '100', 'MAPPING_DICT': {'POPG': 'mappingPOPGlipid17ecc.txt', 'POPC': 'mappingPOPClipid17ecc.txt'}, 'CAL': 'CA', 'TRJ': [['traj.xtc']], 'NPOPC': [75, 75], 'NPOPG': [76, 74], 'NSOD': 150, 'TPR': [['topol.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 108, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPClipid17ecc.txt,POPG,mappingPOPGlipid17ecc.txt', 'CLA': 'CL'}
# 298
# {'GRO': '/media/osollila/Data/tmp/DATABANK/tmp_6-686619/0/conf.gro', 'SOD': 'NA', 'ID': 0, 'NCAL': 0, 'SOL': 'SOL', 'FF_SOURCE': '??', 'POT': 'K', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC_T310K', 'DOI': '10.5281/zenodo.3247435', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'TEMPERATURE': '310', 'NSOL': 25000, 'NPOPE': [0, 0], 'FF': 'gromos-ckp', 'TRJLENGTH': 100010.0, 'POPC': 'POPC', 'FF_DATE': '?/?/????', 'POPG': 'LPOG', 'PREEQTIME': '400', 'UADICTIONARY': {'POPC': 'GROMOS_CKP_POPC'}, 'MAPPING_DICT': {'POPC': 'mappingPOPCgromos-ckp.txt'}, 'CAL': 'CA', 'UNITEDATOM': 'POPC,GROMOS_CKP_POPC', 'TRJ': [['total_4_500.xtc']], 'NPOPC': [250, 250], 'NPOPG': [0, 0], 'NSOD': 0, 'TPR': [['md_0.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 0, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCgromos-ckp.txt', 'CLA': 'CL'}
# 310
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': 'NMRlipids IVa', 'POT': 'M_K_M', 'TIMELEFTOUT': '20', 'SYSTEM': 'POPC30%DHMDMAB_T313K', 'DOI': '10.5281/zenodo.1288297', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'CHOL': 'CHOL', 'TEMPERATURE': '313', 'NSOL': 7966, 'NPOPE': [0, 0], 'FF': 'CHARMM36', 'TRJLENGTH': 200010.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POPG', 'PREEQTIME': '0', 'MAPPING_DICT': {'DHMDMAB': 'mappingDHMDMABcharmm.txt', 'POPC': 'mappingPOPCcharmm.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['run30.xtc']], 'NPOPC': [50, 50], 'NPOPG': [0, 0], 'NSOD': 0, 'TPR': [['run30.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 44, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCcharmm.txt,DHMDMAB,mappingDHMDMABcharmm.txt', 'CLA': 'M_CL_M'}
# 313
# {'SOD': 'NA+', 'ID': 0, 'NCAL': 0, 'SOL': 'SOL', 'FF_SOURCE': '??', 'POT': 'K', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC:POPG(7:3)_T310K', 'DOI': '10.5281/zenodo.3241243', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'TEMPERATURE': '310', 'NSOL': 0, 'NPOPE': [0, 0], 'FF': 'lipid17', 'TRJLENGTH': 100010.0, 'POPC': 'system1', 'FF_DATE': '??', 'POPG': 'system2', 'PREEQTIME': '400', 'MAPPING_DICT': {'POPG': 'mappingPOPGlipid17.txt', 'POPC': 'mappingPOPClipid17.txt'}, 'CAL': 'CA', 'TRJ': [['total_4_500.xtc']], 'NPOPC': [175, 175], 'NPOPG': [75, 75], 'NSOD': 0, 'TPR': [['md_0.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 0, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPClipid17.txt,POPG,mappingPOPGlipid17.txt', 'CLA': 'CL'}
# 310
# {'GRO': '/media/osollila/Data/tmp/DATABANK/tmp_6-244640/0/conf.gro', 'SOD': 'NA', 'ID': 0, 'NCAL': 0, 'SOL': 'SOL', 'FF_SOURCE': '??', 'POT': 'K', 'TIMELEFTOUT': '100', 'SYSTEM': 'POPE_T300K', 'DOI': '10.5281/zenodo.1402449', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'TEMPERATURE': '300', 'NSOL': 11096, 'NPOPE': [64, 64], 'FF': 'berger', 'TRJLENGTH': 400100.0, 'POPC': 'POPC', 'FF_DATE': '?/?/????', 'POPG': 'POPG', 'PREEQTIME': '0', 'UADICTIONARY': {'POPE': 'Berger_POPE', 'POPC': 'Berger_POPC'}, 'MAPPING_DICT': {'POPE': 'mappingPOPEberger.txt', 'POPC': 'mappingPOPCberger.txt'}, 'CAL': 'CA', 'UNITEDATOM': 'POPC,Berger_POPC,POPE,Berger_POPE', 'TRJ': [['md_dt100_OK_centered.xtc']], 'NPOPC': [64, 64], 'NPOPG': [0, 0], 'NSOD': 0, 'TPR': [['md.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 0, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCberger.txt,POPE,mappingPOPEberger.txt', 'CLA': 'CL'}
# 300
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': 'http://www.fos.su.se/~sasha/SLipids/, https://bitbucket.org/hseara/ions/', 'POT': 'M_K_M', 'TIMELEFTOUT': '500', 'SYSTEM': 'POPC_T298K', 'DOI': '10.5281/zenodo.3613573', 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 12800, 'NPOPE': [0, 0], 'FF': 'Slipids', 'TRJLENGTH': 1000100.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POPG', 'PREEQTIME': '0', 'MAPPING_DICT': {'POPG': 'mappingPOPGslipids.txt', 'POPC': 'mappingPOPCslipids.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['PCPG_CA500_extend.xtc']], 'NPOPC': [64, 64], 'NPOPG': [64, 64], 'NSOD': 128, 'TPR': [['PCPG_CA500.tpr']], 'NPOT': '0', 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': '0', 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCslipids.txt,POPG,mappingPOPGslipids.txt', 'CLA': 'M_CL_M'}
# 298
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': 'http://www.fos.su.se/~sasha/SLipids/, https://bitbucket.org/hseara/ions/', 'POT': 'M_K_M', 'TIMELEFTOUT': '100', 'SYSTEM': 'POPC_T298K', 'DOI': '10.5281/zenodo.3613573', 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 12800, 'NPOPE': [0, 0], 'FF': 'Slipids', 'TRJLENGTH': 500100.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POPG', 'PREEQTIME': '0', 'MAPPING_DICT': {'POPG': 'mappingPOPGslipids.txt', 'POPC': 'mappingPOPCslipids.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['PCPG_CA0.xtc']], 'NPOPC': [64, 64], 'NPOPG': [64, 64], 'NSOD': 128, 'TPR': [['PCPG_CA0.tpr']], 'NPOT': '0', 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': '0', 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCslipids.txt,POPG,mappingPOPGslipids.txt', 'CLA': 'M_CL_M'}
# 298
# {'GRO': '/media/osollila/Data/tmp/DATABANK/tmp_6-199452/0/conf.gro', 'SOD': 'NA', 'ID': 0, 'NCAL': 0, 'SOL': 'SOL', 'FF_SOURCE': '??', 'POT': 'K', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPCPOPG7:3_T310K', 'DOI': '10.5281/zenodo.3266240', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'TEMPERATURE': '310', 'NSOL': 25000, 'NPOPE': [0, 0], 'FF': 'gromos-ckp', 'TRJLENGTH': 100010.0, 'POPC': 'POPC', 'FF_DATE': '?/?/????', 'POPG': 'LPOG', 'PREEQTIME': '400', 'UADICTIONARY': {'POPG': 'GROMOS_CKP_POPG', 'POPC': 'GROMOS_CKP_POPC'}, 'MAPPING_DICT': {'POPG': 'mappingPOPGgromos-ckp.txt', 'POPC': 'mappingPOPCgromos-ckp.txt'}, 'CAL': 'CA', 'UNITEDATOM': 'POPC,GROMOS_CKP_POPC,POPG,GROMOS_CKP_POPG', 'TRJ': [['total_4_500.xtc']], 'NPOPC': [175, 175], 'NPOPG': [75, 75], 'NSOD': 150, 'TPR': [['md_0.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 0, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCgromos-ckp.txt,POPG,mappingPOPGgromos-ckp.txt', 'CLA': 'CL'}
# 310
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': '??', 'POT': 'M_K_M', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC_POPG_7:3_T310K', 'DOI': '10.5281/zenodo.3248689', 'NPOPS': [0, 0], 'TEMPERATURE': '310', 'NSOL': 0, 'NPOPE': [0, 0], 'FF': '??', 'TRJLENGTH': 100010.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POPG', 'PREEQTIME': '400', 'MAPPING_DICT': {'POPG': 'mappingPOPGcharmm.txt', 'POPC': 'mappingPOPCcharmm.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['total_4_500.xtc']], 'NPOPC': [175, 175], 'NPOPG': [75, 75], 'NSOD': 150, 'TPR': [['md_0.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 0, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCcharmm.txt,POPG,mappingPOPGcharmm.txt', 'CLA': 'M_CL_M'}
# 310
# {'GRO': '/media/osollila/Data/tmp/DATABANK/tmp_6-243136/0/conf.gro', 'SOD': 'NA', 'ID': 0, 'NCAL': 475, 'SOL': 'SOL', 'FF_SOURCE': 'NMRlipidsIV', 'POT': 'K', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC:POPG(4:1)_T298K_1MCaCl', 'DOI': '10.5281/zenodo.3997184', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 24840, 'NPOPE': [0, 0], 'FF': 'lipid17ecc', 'TRJLENGTH': 300020.0, 'POPC': 'POPC', 'FF_DATE': '?/?/2020', 'POPG': 'POPG', 'PREEQTIME': '100', 'MAPPING_DICT': {'POPG': 'mappingPOPGlipid17ecc.txt', 'POPC': 'mappingPOPClipid17ecc2.txt'}, 'CAL': 'CA', 'TRJ': [['100-400ns.xtc']], 'NPOPC': [175, 175], 'NPOPG': [44, 44], 'NSOD': 88, 'TPR': [['run_400ns.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 950, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPClipid17ecc2.txt,POPG,mappingPOPGlipid17ecc.txt', 'CLA': 'CL'}
# 298
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 451, 'SOL': 'M_SOL_M', 'FF_SOURCE': 'CHARMM-GUI', 'POT': 'M_K_M', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC:POPG(4:1)+1MCaCl_T298K', 'DOI': '10.5281/zenodo.3997037', 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 24927, 'NPOPE': [0, 0], 'FF': 'CHARMM36', 'TRJLENGTH': 289260.0, 'POPC': 'POPC', 'FF_DATE': '?/?/2020', 'POPG': 'POPG', 'PREEQTIME': '100', 'MAPPING_DICT': {'POPG': 'mappingPOPGcharmm.txt', 'POPC': 'mappingPOPCcharmm.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['100-400ns.xtc']], 'NPOPC': [175, 175], 'NPOPG': [44, 44], 'NSOD': 0, 'TPR': [['run_400ns.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 902, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCcharmm.txt,POPG,mappingPOPGcharmm.txt', 'CLA': 'M_CL_M'}
# 298
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': 'NMRlipids IVa', 'POT': 'M_K_M', 'TIMELEFTOUT': '20', 'SYSTEM': 'POPC10%DHMDMAB_T313K', 'DOI': '10.5281/zenodo.1288297', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'CHOL': 'CHOL', 'TEMPERATURE': '313', 'NSOL': 7966, 'NPOPE': [0, 0], 'FF': 'CHARMM36', 'TRJLENGTH': 200010.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POPG', 'PREEQTIME': '0', 'MAPPING_DICT': {'DHMDMAB': 'mappingDHMDMABcharmm.txt', 'POPC': 'mappingPOPCcharmm.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['run10.xtc']], 'NPOPC': [50, 50], 'NPOPG': [0, 0], 'NSOD': 0, 'TPR': [['run10.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 12, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCcharmm.txt,DHMDMAB,mappingDHMDMABcharmm.txt', 'CLA': 'M_CL_M'}
# 313
# {'SOD': 'NA+', 'ID': 0, 'NCAL': 0, 'SOL': 'SOL', 'FF_SOURCE': '??', 'POT': 'K', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC_T310K', 'DOI': '10.5281/zenodo.3237657', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'TEMPERATURE': '310', 'NSOL': 0, 'NPOPE': [0, 0], 'FF': 'lipid17', 'TRJLENGTH': 100010.0, 'POPC': 'system1', 'FF_DATE': '??', 'POPG': 'system2', 'PREEQTIME': '400', 'MAPPING_DICT': {'POPC': 'mappingPOPClipid17.txt'}, 'CAL': 'CA', 'TRJ': [['total_4_500.xtc']], 'NPOPC': [250, 250], 'NPOPG': [0, 0], 'NSOD': 0, 'TPR': [['md_0.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 0, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPClipid17.txt', 'CLA': 'CL'}
# 310
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': '??', 'POT': 'M_K_M', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC_T310K', 'DOI': '10.5281/zenodo.3247813', 'NPOPS': [0, 0], 'TEMPERATURE': '310', 'NSOL': 0, 'NPOPE': [0, 0], 'FF': '??', 'TRJLENGTH': 100010.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POPG', 'PREEQTIME': '400', 'MAPPING_DICT': {'POPC': 'mappingPOPCcharmm.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['total_4_500.xtc']], 'NPOPC': [250, 250], 'NPOPG': [0, 0], 'NSOD': 0, 'TPR': [['md_0.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 0, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCcharmm.txt', 'CLA': 'M_CL_M'}
# 310
# {'SOD': 'NA', 'ID': 0, 'NCAL': 47, 'SOL': 'SOL', 'FF_SOURCE': 'NMRlipidsIV', 'POT': 'K', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC:POPG(4:1)_T298K_0.1MCaCl', 'DOI': '10.5281/zenodo.3997176', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 26124, 'NPOPE': [0, 0], 'FF': 'lipid17ecc', 'TRJLENGTH': 300020.0, 'POPC': 'POPC', 'FF_DATE': '?/?/2020', 'POPG': 'POPG', 'PREEQTIME': '100', 'MAPPING_DICT': {'POPG': 'mappingPOPGlipid17ecc.txt', 'POPC': 'mappingPOPClipid17ecc.txt'}, 'CAL': 'CA', 'TRJ': [['100-400ns.xtc']], 'NPOPC': [175, 175], 'NPOPG': [44, 44], 'NSOD': 88, 'TPR': [['run_400ns.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 94, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPClipid17ecc.txt,POPG,mappingPOPGlipid17ecc.txt', 'CLA': 'CL'}
# 298
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': '??', 'POT': 'M_K_M', 'TIMELEFTOUT': '20', 'SYSTEM': 'POPC_T303K', 'DOI': '10.5281/zenodo.3474863', 'NPOPS': [0, 0], 'TEMPERATURE': '303', 'NSOL': 5120, 'NPOPE': [0, 0], 'FF': 'CHARMM36', 'TRJLENGTH': 500010.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POPG', 'PREEQTIME': '0', 'MAPPING_DICT': {'POPC': 'mappingPOPCcharmm.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['traj_comp.xtc']], 'NPOPC': [64, 64], 'NPOPG': [0, 0], 'NSOD': 0, 'TPR': [['mdrun.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 0, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCcharmm.txt', 'CLA': 'M_CL_M'}
# 303
# {'SOD': 'NA', 'ID': 0, 'NCAL': 0, 'SOL': 'SOL', 'FF_SOURCE': 'NMRlipidsIV', 'POT': 'K', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC:POPG(4:1)_T298K', 'DOI': '10.5281/zenodo.3997154', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 26265, 'NPOPE': [0, 0], 'FF': 'lipid17ecc', 'TRJLENGTH': 300020.0, 'POPC': 'POPC', 'FF_DATE': '?/?/2020', 'POPG': 'POPG', 'PREEQTIME': '100', 'MAPPING_DICT': {'POPG': 'mappingPOPGlipid17ecc.txt', 'POPC': 'mappingPOPClipid17ecc.txt'}, 'CAL': 'CA', 'TRJ': [['100-400ns.xtc']], 'NPOPC': [175, 175], 'NPOPG': [44, 44], 'NSOD': 88, 'TPR': [['run_400ns.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 0, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPClipid17ecc.txt,POPG,mappingPOPGlipid17ecc.txt', 'CLA': 'CL'}
# 298
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': '0', 'SOL': 'M_SOL_M', 'FF_SOURCE': '10.5281/zenodo.3725637', 'POT': 'M_K_M', 'TIMELEFTOUT': '200', 'SYSTEM': 'POPC:POPE(1:1)_T300K', 'DOI': '10.5281/zenodo.3741793', 'NPOPS': [0, 0], 'TEMPERATURE': '300', 'NSOL': 5120, 'NPOPE': [0, 0], 'FF': 'MacRog', 'TRJLENGTH': 500100.0, 'POPC': 'POPC', 'FF_DATE': '26/3/2020', 'POPG': 'POPG', 'PREEQTIME': '0', 'MAPPING_DICT': {'POPC': 'mappingPOPCmacrogFUCHS.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['md_OK_100.xtc']], 'NPOPC': [64, 64], 'NPOPG': [0, 0], 'NSOD': 0, 'TPR': [['md.tpr']], 'NPOT': '0', 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': '0', 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCmacrogFUCHS.txt', 'CLA': 'M_CL_M'}
# 300
# {'SOD': 'NA', 'ID': 0, 'NCAL': 569, 'SOL': 'SOL', 'FF_SOURCE': 'NMRlipidsIV', 'POT': 'K', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC:POPG(1:1)_T298K_1000mM_CaCl', 'DOI': '10.5281/zenodo.3862036', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 29865, 'NPOPE': [0, 0], 'FF': 'lipid17ecc', 'TRJLENGTH': 400020.0, 'POPC': 'POPC', 'FF_DATE': '?/?/2020', 'POPG': 'POPG', 'PREEQTIME': '200', 'MAPPING_DICT': {'POPG': 'mappingPOPGlipid17ecc.txt', 'POPC': 'mappingPOPClipid17ecc.txt'}, 'CAL': 'CA', 'TRJ': [['traj.xtc']], 'NPOPC': [75, 75], 'NPOPG': [76, 74], 'NSOD': 150, 'TPR': [['topol.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 1138, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPClipid17ecc.txt,POPG,mappingPOPGlipid17ecc.txt', 'CLA': 'CL'}
# 298
# {'SOD': 'NA', 'ID': 0, 'NCAL': 0, 'SOL': 'SOL', 'FF_SOURCE': 'NMRlipidsIV', 'POT': 'K', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC:POPG(1:1)_T298K', 'DOI': '10.5281/zenodo.3857816', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 31572, 'NPOPE': [0, 0], 'FF': 'lipid17', 'TRJLENGTH': 200020.0, 'POPC': 'system1', 'FF_DATE': '?/?/2020', 'POPG': 'system2', 'PREEQTIME': '120', 'MAPPING_DICT': {'POPG': 'mappingPOPGlipid17.txt', 'POPC': 'mappingPOPClipid17.txt'}, 'CAL': 'CA', 'TRJ': [['run2.xtc']], 'NPOPC': [76, 74], 'NPOPG': [75, 75], 'NSOD': 150, 'TPR': [['run2.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 0, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPClipid17.txt,POPG,mappingPOPGlipid17.txt', 'CLA': 'CL'}
# 298
# {'SOD': 'SOD', 'ID': 0, 'NCAL': 578, 'SOL': 'TIP3', 'FF_SOURCE': 'CHARMM-GUI', 'POT': 'K', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC:POPG(1:1)+1MCaCl_T298K', 'DOI': '10.5281/zenodo.3997135', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 29766, 'NPOPE': [0, 0], 'FF': 'CHARMM36', 'TRJLENGTH': 300020.0, 'POPC': 'POPC', 'FF_DATE': '?/?/2020', 'POPG': 'POPG', 'PREEQTIME': '100', 'MAPPING_DICT': {'POPG': 'mappingPOPGcharmm.txt', 'POPC': 'mappingPOPCcharmm.txt'}, 'CAL': 'CAL', 'TRJ': [['100-400ns.xtc']], 'NPOPC': [75, 75], 'NPOPG': [75, 75], 'NSOD': 150, 'TPR': [['run_400ns.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 1156, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCcharmm.txt,POPG,mappingPOPGcharmm.txt', 'CLA': 'CLA'}
# 298
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': 'CHARMM-GUI', 'POT': 'M_K_M', 'TIMELEFTOUT': '20', 'SYSTEM': 'POPC_T313K', 'DOI': '10.5281/zenodo.4040423', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'TEMPERATURE': '313', 'NSOL': 9000, 'NPOPE': [0, 0], 'FF': 'CHARMM36', 'TRJLENGTH': 200010.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POPG', 'PREEQTIME': '0', 'MAPPING_DICT': {'POPC': 'mappingPOPCcharmm.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['run.xtc']], 'NPOPC': [100, 100], 'NPOPG': [0, 0], 'NSOD': 0, 'TPR': [['run.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 0, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCcharmm.txt', 'CLA': 'M_CL_M'}
# 313
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': 'http://www.fos.su.se/~sasha/SLipids/, https://bitbucket.org/hseara/ions/', 'POT': 'M_K_M', 'TIMELEFTOUT': '500', 'SYSTEM': 'POPC_T298K', 'DOI': '10.5281/zenodo.3613573', 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 12800, 'NPOPE': [0, 0], 'FF': 'Slipids', 'TRJLENGTH': 1000100.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POPG', 'PREEQTIME': '0', 'MAPPING_DICT': {'POPG': 'mappingPOPGslipids.txt', 'POPC': 'mappingPOPCslipids.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['PCPG_CA200_extend.xtc']], 'NPOPC': [64, 64], 'NPOPG': [64, 64], 'NSOD': 128, 'TPR': [['PCPG_CA200.tpr']], 'NPOT': '0', 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': '0', 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCslipids.txt,POPG,mappingPOPGslipids.txt', 'CLA': 'M_CL_M'}
# 298
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': '??', 'POT': 'M_K_M', 'TIMELEFTOUT': '50', 'SYSTEM': 'POPC_T300K', 'DOI': '10.5281/zenodo.1306800', 'NPOPS': [0, 0], 'TEMPERATURE': '300', 'NSOL': 9767, 'NPOPE': [0, 0], 'FF': 'CHARMM36', 'TRJLENGTH': 300100.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POPG', 'PREEQTIME': '0', 'MAPPING_DICT': {'POPC': 'mappingPOPCcharmm.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['md_dt100_OK_centered.xtc']], 'NPOPC': [128, 128], 'NPOPG': [0, 0], 'NSOD': 0, 'TPR': [['md.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 0, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCcharmm.txt', 'CLA': 'M_CL_M'}
# 300
# {'SOD': 'NA', 'ID': 0, 'NCAL': 57, 'SOL': 'SOL', 'FF_SOURCE': 'NMRlipidsIV', 'POT': 'K', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC:POPG(1:1)_T298K_100mM_CaCl', 'DOI': '10.5281/zenodo.3871590', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 31401, 'NPOPE': [0, 0], 'FF': 'lipid17', 'TRJLENGTH': 198020.0, 'POPC': 'system1', 'FF_DATE': '?/?/2020', 'POPG': 'system2', 'PREEQTIME': '520', 'MAPPING_DICT': {'POPG': 'mappingPOPGlipid17.txt', 'POPC': 'mappingPOPClipid17.txt'}, 'CAL': 'CA', 'TRJ': [['traj.xtc']], 'NPOPC': [75, 75], 'NPOPG': [77, 73], 'NSOD': 150, 'TPR': [['run3.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 114, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPClipid17.txt,POPG,mappingPOPGlipid17.txt', 'CLA': 'CL'}
# 298
# {'SOD': 'SOD', 'ID': 0, 'NCAL': 0, 'SOL': 'TIP3', 'FF_SOURCE': 'CHARMM-GUI', 'POT': 'K', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC:POPG(1:1)_T298K', 'DOI': '10.5281/zenodo.3997116', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 31500, 'NPOPE': [0, 0], 'FF': 'CHARMM36', 'TRJLENGTH': 300020.0, 'POPC': 'POPC', 'FF_DATE': '?/?/2020', 'POPG': 'POPG', 'PREEQTIME': '100', 'MAPPING_DICT': {'POPG': 'mappingPOPGcharmm.txt', 'POPC': 'mappingPOPCcharmm.txt'}, 'CAL': 'CA', 'TRJ': [['100-400ns.xtc']], 'NPOPC': [75, 75], 'NPOPG': [75, 75], 'NSOD': 150, 'TPR': [['run_400ns.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 0, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCcharmm.txt,POPG,mappingPOPGcharmm.txt', 'CLA': 'CL'}
# 298
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': 'http://www.fos.su.se/~sasha/SLipids/', 'POT': 'M_K_M', 'TIMELEFTOUT': '0', 'SYSTEM': 'POPC:POPE_1:1_T298K', 'DOI': '10.5281/zenodo.3605386', 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 9000, 'NPOPE': [50, 50], 'FF': 'Slipids', 'TRJLENGTH': 300100.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POPG', 'PREEQTIME': '200', 'MAPPING_DICT': {'POPE': 'mappingPOPEslipids.txt', 'POPC': 'mappingPOPCslipids.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['pcpe_slipids.xtc']], 'NPOPC': [50, 50], 'NPOPG': [0, 0], 'NSOD': 0, 'TPR': [['pcpe_slipids.tpr']], 'NPOT': '0', 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': '0', 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCslipids.txt,POPE,mappingPOPEslipids.txt', 'CLA': 'M_CL_M'}
# 298
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': '??', 'POT': 'M_K_M', 'TIMELEFTOUT': '100', 'SYSTEM': 'POPC20%chol_T303K', 'DOI': '10.5281/zenodo.14067', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'CHOL': 'CHOL', 'TEMPERATURE': '303', 'NSOL': 0, 'NPOPE': [0, 0], 'FF': 'CHARMM36', 'TRJLENGTH': 200020.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POPG', 'PREEQTIME': '0', 'MAPPING_DICT': {'POPC': 'mappingPOPCcharmm.txt', 'CHOL': 'mappingCHOLESTEROLcharmm.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['POPC_20CHL.xtc']], 'NPOPC': [50, 50], 'NPOPG': [0, 0], 'NSOD': 0, 'TPR': [['POPC_20CHL.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 0, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCcharmm.txt,CHOL,mappingCHOLESTEROLcharmm.txt', 'CLA': 'M_CL_M'}
# 303
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': '??', 'POT': 'M_K_M', 'TIMELEFTOUT': '100', 'SYSTEM': 'POPC_T303K', 'DOI': '10.5281/zenodo.14066', 'NCHOL': [0, 0], 'NPOPS': [0, 0], 'TEMPERATURE': '303', 'NSOL': 0, 'NPOPE': [0, 0], 'FF': 'CHARMM36', 'TRJLENGTH': 150700.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POPG', 'PREEQTIME': '0', 'MAPPING_DICT': {'POPC': 'mappingPOPCcharmm.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['POPC_0CHL.xtc']], 'NPOPC': [64, 64], 'NPOPG': [0, 0], 'NSOD': 0, 'TPR': [['POPC_0CHL.tpr']], 'NPOT': 0, 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': 0, 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCcharmm.txt', 'CLA': 'M_CL_M'}
# 303
# {'SOD': 'M_NA_M', 'ID': 0, 'NCAL': 0, 'SOL': 'M_SOL_M', 'FF_SOURCE': '??', 'POT': 'M_K_M', 'TIMELEFTOUT': '70', 'SYSTEM': 'POPC_T298K', 'DOI': '10.5281/zenodo.166034', 'NPOPS': [0, 0], 'TEMPERATURE': '298', 'NSOL': 23943, 'NPOPE': [0, 0], 'FF': 'Slipids', 'TRJLENGTH': 100100.0, 'POPC': 'POPC', 'FF_DATE': '??', 'POPG': 'POPG', 'PREEQTIME': '0', 'MAPPING_DICT': {'POPC': 'mappingPOPCslipids.txt'}, 'CAL': 'M_CA_M', 'TRJ': [['popc00_T298_every100ps.xtc']], 'NPOPC': [256, 256], 'NPOPG': [0, 0], 'NSOD': 0, 'TPR': [['popc00_T298_every100ps.tpr']], 'NPOT': '0', 'SOFTWARE': 'gromacs', 'POPE': 'POPE', 'NCLA': '0', 'POPS': 'POPS', 'MAPPING': 'POPC,mappingPOPCslipids.txt', 'CLA': 'M_CL_M'}
# 298

# %%
# Demonstration of reading the databank
# print file paths for certain DOIs

# List of lipids that will be analyzed
lipids = {'POPC', 'POPG','POPE','POPS'} 
angles = []

#DOIs = {'POPC' :'10.5281/zenodo.3474862','POPG' :'10.5281/zenodo.1011096','POPS' :'10.5281/zenodo.1129415','POPE' :'10.5281/zenodo.2641987'}

dois = ['10.5281/zenodo.4040423','10.5281/zenodo.1288297'] # CHARMM with cationic surfactant

# This walks through the files in the databank
# Dictionaries saved as README.yaml are read into 'readme' dictionary

count = 0

for subdir, dirs, files in os.walk(r'../Data/Simulations/'):
    for filename in files:
        filepath = subdir + os.sep + filename
        if filepath.endswith("README.yaml"):
            READMEfilepath = subdir + '/README.yaml'
            with open(READMEfilepath) as yaml_file:
                readme = yaml.load(yaml_file, Loader=yaml.FullLoader)
                #for molname in lipids:
                doi = readme.get('DOI')
                trj = readme.get('TRJ')
                tpr = readme.get('TPR')
                trj_name = subdir + '/' + readme.get('TRJ')[0][0]
                tpr_name = subdir + '/' + readme.get('TPR')[0][0]
                gro_name = subdir + '/conf.gro'
                trj_url = download_link(doi, trj[0][0])
                tpr_url = download_link(doi, tpr[0][0])
                EQtime=float(readme.get('TIMELEFTOUT'))*1000
                
                if doi in dois:
                    print(readme.get('NCLA')/(readme.get('NCLA')+2*readme.get('NPOPC')[0]),subdir)
                    #print(readme.get('NCLA')/(readme.get('NPOPC')[0]))
                
                #for lipid in lipids:
                #    if DOIs[lipid] in readme.get('DOI'):
                #        print(lipid,subdir)
# Out:
# 0.23076923076923078 ../Data/Simulations/702/d04/702d047ee14fb2c6b8ceb1666df45f0783272d8c/50161179ab704faeaf1644957545a77fe97a1063
# 0.46808510638297873 ../Data/Simulations/b86/c00/b86c00db1e4696dc7fa04770509c1cea31d4bf63/3c4f254f6ac8cba7eb9b53b430acba33ec2f5ce7
# 0.3055555555555556 ../Data/Simulations/66f/81c/66f81c7905a792bfdc935f463c56af8bb1a1e31f/7050b07cc869d03e5645bc7935a4989dc0480766
# 0.10714285714285714 ../Data/Simulations/ed4/076/ed4076a232ce5d87dc4a244164604a0b91d9d877/25731b859c4bc2652de35ead4f799ac1d922df28
# 0.0 ../Data/Simulations/007/ed1/007ed172073ee268b07f29ecd413eb9de13a3d47/895cd634e9106b949e0c15cd8873592748b66fed
